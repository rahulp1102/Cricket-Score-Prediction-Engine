#
#            city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# /var/folders/pz/l5jhl425705d3dx774l944540000gn/T/ipykernel_95751/3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# /var/folders/pz/l5jhl425705d3dx774l944540000gn/T/ipykernel_95751/1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'last_five']]
# Out:
#     batting_team bowling_team        city  current_score  balls_left  \
# 0    West Indies        India  Lauderhill              0         119
# 1    West Indies        India  Lauderhill              0         118
# 2    West Indies        India  Lauderhill              0         117
# 3    West Indies        India  Lauderhill              1         116
# 4    West Indies        India  Lauderhill              1         115
# ..           ...          ...         ...            ...         ...
# 117     Pakistan  New Zealand       Dubai            158           4
# 118     Pakistan  New Zealand       Dubai            158           3
# 119     Pakistan  New Zealand       Dubai            159           2
# 120     Pakistan  New Zealand       Dubai            161           1
# 121     Pakistan  New Zealand       Dubai            161           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1               9  0.000000        NaN
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team        city  current_score  balls_left  \
# 54904    Australia    Sri Lanka   Melbourne            115          21
# 23329    Sri Lanka  West Indies  Nottingham             73          80
#
#        wickets_left        crr  last_five  runs_x
# 54904             5   6.969697       38.0     154
# 23329            10  10.950000       52.0     192

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 14135       England      Pakistan     Abu Dhabi             57          65
# 51488   West Indies    Bangladesh        Mirpur             47          83
# 8119    West Indies      Pakistan       Karachi             66          84
# 25354         India   New Zealand      Hamilton            128          27
# 42568         India     Sri Lanka      St Lucia            137          19
# ...             ...           ...           ...            ...         ...
# 49823      Pakistan  South Africa        Lahore            111          18
# 49898       England   New Zealand      Auckland            103          64
# 10023  South Africa       England   Southampton             38          88
# 21966       England  South Africa  Johannesburg             59          76
# 29377      Pakistan  South Africa    Nottingham             86          54
#
#        wickets_left        crr  last_five
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
],
remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.9877980947494507
# 1.5722756385803223

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.7.6'

# %%
pip install --upgrade scikit-learn xgboost
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 648 kB/s eta 0:00:01
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.7.6
#     Uninstalling xgboost-1.7.6:
#       Successfully uninstalled xgboost-1.7.6
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predicting the scores using the test data
y_pred_xgboost = xgboost_model.predict(X_test)  # Predictions for XGBoost
y_pred_rf = rf_model.predict(X_test)  # Predictions for Random Forest

# Actual scores (test set)
y_actual = y_test

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(np.arange(len(y_actual)), y_actual, label="Actual Scores", color='blue', marker='o', markersize=5)
plt.plot(np.arange(len(y_pred_xgboost)), y_pred_xgboost, label="Predicted Scores (XGBoost)", color='green', linestyle='--')
plt.plot(np.arange(len(y_pred_rf)), y_pred_rf, label="Predicted Scores (Random Forest)", color='red', linestyle='--')

plt.title('Prediction vs Actual Scores', fontsize=16)
plt.xlabel('Test Data Index', fontsize=14)
plt.ylabel('Scores (Runs)', fontsize=14)
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display the plot
st.pyplot(plt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 5>()
#       2 import numpy as np
#       4 # Predicting the scores using the test data
# ----> 5 y_pred_xgboost = xgboost_model.predict(X_test)  # Predictions for XGBoost
#       6 y_pred_rf = rf_model.predict(X_test)  # Predictions for Random Forest
#       8 # Actual scores (test set)
#
# NameError: name 'xgboost_model' is not defined
